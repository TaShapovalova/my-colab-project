# %% [markdown]
# <a href="https://colab.research.google.com/github/TaShapovalova/my-colab-project/blob/main/MODULE__3_case5%E2%9D%8C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp "/content/drive/MyDrive/Материалы для выполнения состязательной атаки (для кейса 5)-20260608.zip" "/content/lab.zip"
# Out:
# cp: cannot stat '/content/drive/MyDrive/Материалы для выполнения состязательной атаки (для кейса 5)-20260608.zip': No such file or directory

# %%
# !ls "/content/drive/MyDrive/"
# Out:
# 'Colab Notebooks'
# 'Копия нотариуса'
# 'Материалы для выполнения атаки отравлением (для кейса 5)-20260608.zip'
# 'ОБЪЯВЛЕНИЕ 18.05.2022.docx'
# 'ОБЪЯВЛЕНИЕ 18.05.2022.gdoc'
# 'Чат WhatsApp с Дом 40.txt'
# 'Чат с админом (Камшат)'

# %%
# !cp "/content/drive/MyDrive/Материалы для выполнения атаки отравлением (для кейса 5)-20260608.zip" "/content/lab.zip"

# %%
# !unzip -q "lab.zip"

# %%
# !unzip -q "voice_attack.zip" && echo "-----ПОИСК-----" && find . -name "main.py"
# Out:
# unzip:  cannot find or open voice_attack.zip, voice_attack.zip.zip or voice_attack.zip.ZIP.

# %%
# !ls -1 /content/
# Out:
# Colab_Poisoning_attack_voice_2025.ipynb
# drive
# Kaggle_Poisoning_attack.ipynb
# Kaggle_Описание.docx
# lab.zip
# poison_data.zip
# poison_hopskip.zip
# Poisoning_attack.ipynb
# sample_data

# %%
# !unzip -q "Colab_Poisoning_attack_voice/voice_attack.zip"
# Out:
# unzip:  cannot find or open Colab_Poisoning_attack_voice/voice_attack.zip, Colab_Poisoning_attack_voice/voice_attack.zip.zip or Colab_Poisoning_attack_voice/voice_attack.zip.ZIP.

# %%
# !find "Colab_Poisoning_attack_voice" -name "main.py"
# Out:
# find: ‘Colab_Poisoning_attack_voice’: No such file or directory

# %%
Colab_Poisoning_attack_voice/voice_attack/main.py
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2440/3367579300.py in <cell line: 0>()
# ----> 1 Colab_Poisoning_attack_voice/voice_attack/main.py
#
# NameError: name 'Colab_Poisoning_attack_voice' is not defined

# %%
# !ls -1 "Colab_Poisoning_attack_voice"
# Out:
# ls: cannot access 'Colab_Poisoning_attack_voice': No such file or directory

# %%
# !unzip -q "poison_hopskip.zip" && echo "-----ПОИСК-----" && find . -name "main.py"
# Out:
# -----ПОИСК-----
# ./voice_attack/main.py

# %%
# !python ./voice_attack/main.py
# Out:
# Traceback (most recent call last):
#   File "/content/./voice_attack/main.py", line 17, in <module>
#     from art.attacks.evasion import HopSkipJump
# ModuleNotFoundError: No module named 'art'

# %%
# !pip install adversarial-robustness-toolbox
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 26.2 MB/s eta 0:00:00
# ...

# %%
# !python ./voice_attack/main.py
# Out:
# 2026-06-09 13:55:24.136565: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Embedding size is 512, encoder SAP.
# Initialised AngleProto
# Initialised Adam optimizer
# Initialised step LR scheduler
# /content/voice_attack/SpeakerNet.py:66: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = GradScaler()
# Traceback (most recent call last):
#   File "/content/./voice_attack/main.py", line 293, in <module>
#     main()
#   File "/content/./voice_attack/main.py", line 242, in main
#     dataset, labels = create_attacked_dataset(test_list)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
# !mkdir -p /content/voice_attack/data/
# !mv /content/test_list.txt /content/voice_attack/data/test_list.txt

# %%
# !ls -R ./voice_attack/
# Out:
# ./voice_attack/:
# data		  loss	   models     __pycache__  SpeakerNet.py     utils.py
# DatasetLoader.py  main.py  optimizer  scheduler    tuneThreshold.py
#
# ./voice_attack/data:
# test_list.txt
#
# ./voice_attack/loss:
# angleproto.py  __pycache__
#
# ./voice_attack/loss/__pycache__:
# angleproto.cpython-312.pyc
#
# ./voice_attack/models:
# __pycache__  ResNetBlocks.py  ResNetSE34L.py
#
# ./voice_attack/models/__pycache__:
# ResNetBlocks.cpython-312.pyc  ResNetSE34L.cpython-312.pyc
#
# ./voice_attack/optimizer:
# adam.py  __pycache__
#
# ./voice_attack/optimizer/__pycache__:
# adam.cpython-312.pyc
#
# ./voice_attack/__pycache__:
# DatasetLoader.cpython-312.pyc  tuneThreshold.cpython-312.pyc
# SpeakerNet.cpython-312.pyc     utils.cpython-312.pyc
#
# ./voice_attack/scheduler:
# __pycache__  steplr.py
#
# ./voice_attack/scheduler/__pycache__:
# steplr.cpython-312.pyc

# %%
# !cd ./voice_attack && python main.py
# Out:
# 2026-06-09 13:59:38.827665: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Embedding size is 512, encoder SAP.
# Initialised AngleProto
# Initialised Adam optimizer
# Initialised step LR scheduler
# /content/voice_attack/SpeakerNet.py:66: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = GradScaler()
# Traceback (most recent call last):
#   File "/content/voice_attack/main.py", line 293, in <module>
#     main()
#   File "/content/voice_attack/main.py", line 239, in main
#     trainer.loadParameters('baseline_lite_ap.model')
#   File "/content/voice_attack/SpeakerNet.py", line 248, in loadParameters
# ...

# %%
# !ls -1 ./voice_attack/models/
# Out:
# __pycache__
# ResNetBlocks.py
# ResNetSE34L.py

# %%
# !find /content -name "*.pth" -o -name "*.pt" -o -name "*baseline*" 2>/dev/null
# Out:
# /content/baseline_lite_ap.model

# %%
# !cd ./voice_attack && python main.py
# Out:
# 2026-06-09 14:07:30.598398: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Embedding size is 512, encoder SAP.
# Initialised AngleProto
# Initialised Adam optimizer
# Initialised step LR scheduler
# /content/voice_attack/SpeakerNet.py:66: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = GradScaler()
# Traceback (most recent call last):
#   File "/content/voice_attack/main.py", line 293, in <module>
#     main()
#   File "/content/voice_attack/main.py", line 239, in main
#     trainer.loadParameters('baseline_lite_ap.model')
#   File "/content/voice_attack/SpeakerNet.py", line 248, in loadParameters
# ...

# %%
FileNotFoundError: 'baseline_lite_ap.model'

# %%
# !mv ./voice_attack/models/baseline_lite_ap_model ./voice_attack/models/baseline_lite_ap.model
# Out:
# mv: cannot stat './voice_attack/models/baseline_lite_ap_model': No such file or directory

# %%
# !cp /content/baseline_lite_ap.model ./voice_attack/models/baseline_lite_ap.model

# %%
# !cd ./voice_attack && python main.py
# Out:
# 2026-06-09 14:10:46.685077: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Embedding size is 512, encoder SAP.
# Initialised AngleProto
# Initialised Adam optimizer
# Initialised step LR scheduler
# /content/voice_attack/SpeakerNet.py:66: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = GradScaler()
# Traceback (most recent call last):
#   File "/content/voice_attack/main.py", line 293, in <module>
#     main()
#   File "/content/voice_attack/main.py", line 239, in main
#     trainer.loadParameters('baseline_lite_ap.model')
#   File "/content/voice_attack/SpeakerNet.py", line 248, in loadParameters
# ...

# %%
# !ls -la ./voice_attack/models/
# Out:
# total 5752
# drwxr-xr-x 3 root root    4096 Jun  9 14:10 .
# drwxr-xr-x 8 root root    4096 Jun  9 13:57 ..
# -rw-r--r-- 1 root root 5862646 Jun  9 14:10 baseline_lite_ap.model
# drwxr-xr-x 2 root root    4096 Jun  9 13:55 __pycache__
# -rw-r--r-- 1 root root    2821 Jul 24  2023 ResNetBlocks.py
# -rw-r--r-- 1 root root    4734 Jul 24  2023 ResNetSE34L.py

# %%
# !cp ./voice_attack/models/baseline_lite_ap.model ./voice_attack/baseline_lite_ap.model

# %%
# !cd ./voice_attack && python main.py
# Out:
# 2026-06-09 14:12:52.789531: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Embedding size is 512, encoder SAP.
# Initialised AngleProto
# Initialised Adam optimizer
# Initialised step LR scheduler
# /content/voice_attack/SpeakerNet.py:66: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = GradScaler()
# dataset loading...
# Traceback (most recent call last):
#   File "/content/voice_attack/main.py", line 293, in <module>
#     main()
#   File "/content/voice_attack/main.py", line 242, in main
#     dataset, labels = create_attacked_dataset(test_list)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
